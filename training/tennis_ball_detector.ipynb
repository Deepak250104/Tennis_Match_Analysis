# %% [markdown]
# # Get Dataset

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # Load environment variables from .env file

API_KEY = os.getenv("KEY")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=API_KEY)
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# ...
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 1882.50it/s]

# %% [markdown]
# Moving files

# %%
import shutil

# %%
shutil.move(r"tennis-ball-detection-6\train",
r"tennis-ball-detection-6\tennis-ball-detection-6\train",
)

shutil.move(r"tennis-ball-detection-6\test",
r"tennis-ball-detection-6\tennis-ball-detection-6\test",
)

shutil.move(r"tennis-ball-detection-6\valid",
r"tennis-ball-detection-6\tennis-ball-detection-6\valid",
)
# Out:
# 'tennis-ball-detection-6\\tennis-ball-detection-6\\valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# ...
# Ultralytics 8.3.82 🚀 Python-3.11.0 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
